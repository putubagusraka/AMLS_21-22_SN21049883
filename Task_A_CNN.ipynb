# %%
from project_functions import *

# %% [markdown]
# ## Data Preprocessing (Training)

# %%
data_path="dataset/"
file = "label.csv"

x_train_val, x_test, y_train_val, y_test = preprocessing_data(data_path, file, 'training', 'task_a','cnn')
# Out:
# Distribution of image categories:
# Counter({'tumor': 2546, 'no_tumor': 454})
# Distribution of image categories post-SMOTE:
# Counter({'tumor': 2546, 'no_tumor': 2546})
# C:\Software\Anaconda\lib\site-packages\sklearn\preprocessing\_label.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Finding Best Parameters (CNN with GridSearchCV)

# %%
#find_CNN_params(x_train_val, y_train_val, x_test, y_test, 'task_a')

# %% [markdown]
# ## Training and Validation (CNN) with K-fold Cross Validation

# %%
train_CNN(x_train_val,y_train_val, 'task_a')
# Out:
# CNN training with 5-Fold Cross Validation.
# Epoch 1/50
# 92/92 [==============================] - 6s 25ms/step - loss: 1.2078 - acc: 0.5709 - val_loss: 0.6964 - val_acc: 0.5184
# Epoch 2/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.7494 - acc: 0.6020 - val_loss: 0.7014 - val_acc: 0.5184
# Epoch 3/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6675 - acc: 0.6218 - val_loss: 1.6619 - val_acc: 0.5184
# Epoch 4/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6410 - acc: 0.6245 - val_loss: 0.8077 - val_acc: 0.5123
# Epoch 5/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6237 - acc: 0.6477 - val_loss: 0.8224 - val_acc: 0.5061
# Epoch 6/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6113 - acc: 0.6630 - val_loss: 0.7111 - val_acc: 0.6012
# Epoch 7/50
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6110 - acc: 0.6521 - val_loss: 0.8116 - val_acc: 0.5429
# ...

# %% [markdown]
# # Testing (using splitted sample data)

# %%
test_CNN(x_test,y_test,'task_a')
# Out:
# Accuracy for test data: 0.6869479882237488
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_20 (Conv2D)           (None, 128, 128, 32)      832
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64, 64, 32)        128
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# ...

# %% [markdown]
# ## Test Task A CNN

# %% [markdown]
# # TO DO!!!

# %%
#add a simple CNN model
#ablation study
