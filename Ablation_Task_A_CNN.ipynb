# %%
from project_functions import *
from ablation_functions import *

# %% [markdown]
# # CNN Task A Model with no Dropout, for ablation studies

# %% [markdown]
# ## Data Preprocessing (Training)

# %%
data_path="dataset/"
file = "label.csv"

x_train_val, x_test, y_train_val, y_test = preprocessing_data(data_path, file, 'training', 'task_a','cnn')
# Out:
# Distribution of image categories:
# Counter({'tumor': 2546, 'no_tumor': 454})
# Distribution of image categories post-SMOTE:
# Counter({'tumor': 2546, 'no_tumor': 2546})

# %% [markdown]
# ## Training and Validation (CNN) with K-fold Cross Validation

# %%
ablation_train_CNN(x_train_val,y_train_val, 'task_a')
# Out:
# CNN training with 5-Fold Cross Validation.
# Epoch 1/50
# 92/92 [==============================] - 12s 40ms/step - loss: 0.9181 - acc: 0.5839 - val_loss: 0.9255 - val_acc: 0.4816
# Epoch 2/50
# 92/92 [==============================] - 3s 30ms/step - loss: 0.6306 - acc: 0.6409 - val_loss: 1.1906 - val_acc: 0.4816
# Epoch 3/50
# 92/92 [==============================] - 3s 30ms/step - loss: 0.6060 - acc: 0.6613 - val_loss: 0.8237 - val_acc: 0.4816
# Epoch 4/50
# 92/92 [==============================] - 3s 30ms/step - loss: 0.5832 - acc: 0.6756 - val_loss: 1.6085 - val_acc: 0.4816
# Epoch 5/50
# 92/92 [==============================] - 3s 30ms/step - loss: 0.5858 - acc: 0.6722 - val_loss: 1.9132 - val_acc: 0.4755
# Epoch 6/50
# 92/92 [==============================] - 3s 30ms/step - loss: 0.5745 - acc: 0.6743 - val_loss: 0.7742 - val_acc: 0.5184
# Epoch 7/50
# 92/92 [==============================] - 3s 31ms/step - loss: 0.5535 - acc: 0.6913 - val_loss: 0.6884 - val_acc: 0.5706
# ...

# %% [markdown]
# # Testing (using splitted sample data)

# %%
ablation_test_CNN(x_test,y_test,'task_a')
# Out:
# Accuracy for test data: 0.6290480863591756
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_20 (Conv2D)           (None, 128, 128, 64)      1664
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# ...
