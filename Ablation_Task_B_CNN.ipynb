# %%
from project_functions import *
from ablation_functions import *

# %% [markdown]
# # CNN Task B Model with no Dropout, for ablation studies

# %% [markdown]
# ## Data Preprocessing (Training)

# %%
data_path="dataset/"
file = "label.csv"

x_train_val, x_test, y_train_val, y_test = preprocessing_data(data_path, file, 'training', 'task_b', 'cnn')
# Out:
# Distribution of image categories:
# Counter({'glioma_tumor': 860, 'meningioma_tumor': 855, 'pituitary_tumor': 831, 'no_tumor': 454})
# Distribution of image categories post-SMOTE:
# Counter({'no_tumor': 860, 'glioma_tumor': 860, 'meningioma_tumor': 855, 'pituitary_tumor': 831})

# %% [markdown]
# ## Training and Validation (KFold CV)

# %%
ablation_train_CNN(x_train_val, y_train_val, 'task_b')
# Out:
# CNN training with 5-Fold Cross Validation.
# Epoch 1/50
# 62/62 [==============================] - 7s 45ms/step - loss: 1.7967 - acc: 0.5094 - val_loss: 2.7642 - val_acc: 0.2477
# Epoch 2/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.8313 - acc: 0.6818 - val_loss: 4.2347 - val_acc: 0.2385
# Epoch 3/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.7079 - acc: 0.7353 - val_loss: 3.8171 - val_acc: 0.2431
# Epoch 4/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.5753 - acc: 0.7981 - val_loss: 4.1913 - val_acc: 0.2431
# Epoch 5/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.5543 - acc: 0.8129 - val_loss: 3.3455 - val_acc: 0.3486
# Epoch 6/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.4671 - acc: 0.8394 - val_loss: 2.0049 - val_acc: 0.3899
# Epoch 7/50
# 62/62 [==============================] - 2s 29ms/step - loss: 0.4037 - acc: 0.8638 - val_loss: 1.4499 - val_acc: 0.5872
# ...

# %% [markdown]
# ## Testing (using splitted sample data)

# %%
ablation_test_CNN(x_test, y_test, 'task_b')
# Out:
# Accuracy for test data: 0.8005865102639296
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_20 (Conv2D)           (None, 128, 128, 64)      1664
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# ...
